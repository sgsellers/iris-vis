# %%
# %pylab inline
from astropy.io import fits
from scipy.optimize import curve_fit
from scipy.interpolate import interp1d
import matplotlib.dates as mdates
import datetime as dt

test = fits.open("CII_1335_bisector_velocities.fits")
time_obs = np.load('iris_times.npy')
x_lims = mdates.date2num(time_obs)

# fig = plt.figure(figsize = (10,10))
# ax = fig.add_subplot(131)
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(131)
ax.imshow(np.rot90(np.mean(np.nan_to_num(test[0].data[27:,1050:1700,0:3]),axis = 2)),
            cmap = 'viridis',vmin = -50,vmax = 50,aspect='auto',
           extent = [0,len(test[0].data[:,0,0]),x_lims[1700],x_lims[1050]],origin = "lower-left")
ax.yaxis_date()
date_format = mdates.DateFormatter('%H:%M:%S')
ax.yaxis.set_major_formatter(date_format)

ax2 = fig.add_subplot(132)
ax2.imshow(np.rot90(np.mean(np.nan_to_num(test[0].data[27:,1050:1700,3:6]),axis = 2)),
           cmap = 'viridis',vmin = -50,vmax = 50,aspect='auto',
           extent = [0,len(test[0].data[:,0,0]),x_lims[1700],x_lims[1050]],origin = 'lower-left')
ax2.yaxis_date()
ax2.yaxis.set_major_formatter(date_format)
ax2.get_yaxis().set_visible(False)

ax3 = fig.add_subplot(133)
ax3.imshow(np.rot90(np.mean(np.nan_to_num(test[0].data[27:,1050:1700,6:]),axis = 2)),
           cmap = 'viridis',vmin = -50,vmax = 50,aspect='auto',
           extent = [0,len(test[0].data[:,0,0]),x_lims[1700],x_lims[1050]],origin='lower-left')
ax3.yaxis_date()
ax3.yaxis.set_major_formatter(date_format)
ax3.get_yaxis().set_visible(False)


plt.tight_layout()
# fig.subplots_adjust(right=0.8)

# cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])

# fig.colorbar(ax3, cax=cbar_ax)
plt.show()
# print(x_lims)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# 2014-10-25T16:32:21
# 2014-10-25T17:30:28
# /home/local/anaconda3/lib/python3.4/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['test']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-dbae80954de0> in <module>()
#      10 print(time_obs[1050])
#      11 print(time_obs[1700])
# ---> 12 x_lims = mdates.date2num(time_obs)
#      13
#      14 # fig = plt.figure(figsize = (10,10))
#
# /home/local/anaconda3/lib/python3.4/site-packages/matplotlib/dates.py in date2num(d)
#     378         if not d.size:
#     379             return d
# --> 380         return _to_ordinalf_np_vectorized(d)
#     381
#     382
#
# ...
