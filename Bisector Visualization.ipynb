# %%
# %pylab inline
from astropy.io import fits
from scipy.optimize import curve_fit
from scipy.interpolate import interp1d

test = fits.open("SiIV_1403_bisector_velocities.fits")
print(test[0].data.shape)
print(np.amin(np.nan_to_num(test[0].data[:,:,5])))
print(np.amax(np.nan_to_num(test[0].data[:,:,5])))
print(np.mean(np.abs(np.nan_to_num(test[0].data[:,:,5])[np.nan_to_num(test[0].data[:,:,5]) != 0.])))
fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(131)
ax = imshow(np.rot90(np.mean(np.nan_to_num(test[0].data[27:,:,0:3]),axis = 2)),cmap = 'viridis',vmin = -30,vmax = 30,aspect='auto')
ax2 = fig.add_subplot(132)
ax2 = imshow(np.rot90(np.mean(np.nan_to_num(test[0].data[27:,:,3:6]),axis = 2)),cmap = 'viridis',vmin = -30,vmax = 30,aspect='auto')
ax3 = fig.add_subplot(133)
ax3 = imshow(np.rot90(np.mean(np.nan_to_num(test[0].data[27:,:,6:]),axis = 2)),cmap = 'viridis',vmin = -30,vmax = 30,aspect='auto')
#cbar1 = fig.colorbar(ax1)
cbar3 = fig.colorbar(ax3)
plt.show()
test[0].header
# Out:
# Populating the interactive namespace from numpy and matplotlib
# (129, 2040, 8)
# -75.67246733560648
# 78.73172623825927
# 3.7882755368646017
# /home/sean/anaconda3/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['test']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# SIMPLE  =                    T / Written by IDL:  Fri Oct 20 15:38:57 2017
# BITPIX  =                  -64 / Number of bits per data pixel
# NAXIS   =                    3 / Number of data axes
# NAXIS1  =                    8
# NAXIS2  =                 2040
# NAXIS3  =                  129
# EXTEND  =                    T / FITS data may contain extensions
# INSTRUME= 'IRIS    '           / Data generated in IRIS format
# DATA_LEV=              3.00000 / Data level
# LVL_NUM =              3.00000 / Data level
# ...

# %%
# %pylab inline
from astropy.io import fits
from scipy.optimize import curve_fit
from scipy.interpolate import interp1d

test = fits.open("CII_1335_bisector_velocities.fits")
print(test[0].data.shape)
print(np.amin(np.nan_to_num(test[0].data[:,:,5])))
print(np.amax(np.nan_to_num(test[0].data[:,:,5])))
print(np.mean(np.abs(np.nan_to_num(test[0].data[:,:,5])[np.nan_to_num(test[0].data[:,:,5]) != 0.])))
fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(131)
ax = imshow(np.rot90(np.mean(np.nan_to_num(test[0].data[27:,:,0:3]),axis = 2)),cmap = 'viridis',vmin = -30,vmax = 30,aspect='auto')
ax2 = fig.add_subplot(132)
ax2 = imshow(np.rot90(np.mean(np.nan_to_num(test[0].data[27:,:,3:6]),axis = 2)),cmap = 'viridis',vmin = -30,vmax = 30,aspect='auto')
ax3 = fig.add_subplot(133)
ax3 = imshow(np.rot90(np.mean(np.nan_to_num(test[0].data[27:,:,6:]),axis = 2)),cmap = 'viridis',vmin = -30,vmax = 30,aspect='auto')
#cbar1 = fig.colorbar(ax1)
cbar3 = fig.colorbar(ax3)
plt.show()
test[0].header
# Out:
# Populating the interactive namespace from numpy and matplotlib
# (129, 2040, 8)
# /home/sean/anaconda3/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['test']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# -74.21153117670664
# 77.7772383395686
# 2.0370106494974527
# SIMPLE  =                    T / Written by IDL:  Fri Oct 20 15:38:57 2017
# BITPIX  =                  -64 / Number of bits per data pixel
# NAXIS   =                    3 / Number of data axes
# NAXIS1  =                    8
# NAXIS2  =                 2040
# NAXIS3  =                  129
# EXTEND  =                    T / FITS data may contain extensions
# INSTRUME= 'IRIS    '           / Data generated in IRIS format
# DATA_LEV=              3.00000 / Data level
# LVL_NUM =              3.00000 / Data level
# ...

# %%
# %pylab inline
from astropy.io import fits
from scipy.optimize import curve_fit
from scipy.interpolate import interp1d

test = fits.open("CII_1336_bisector_velocities.fits")
print(test[0].data.shape)
print(np.amin(np.nan_to_num(test[0].data[:,:,5])))
print(np.amax(np.nan_to_num(test[0].data[:,:,5])))
print(np.mean(np.abs(np.nan_to_num(test[0].data[:,:,5])[np.nan_to_num(test[0].data[:,:,5]) != 0.])))
fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(131)
ax = imshow(np.rot90(np.mean(np.nan_to_num(test[0].data[27:,:,0:3]),axis = 2)),cmap = 'viridis',vmin = -30,vmax = 30,aspect='auto')
ax2 = fig.add_subplot(132)
ax2 = imshow(np.rot90(np.mean(np.nan_to_num(test[0].data[27:,:,3:6]),axis = 2)),cmap = 'viridis',vmin = -30,vmax = 30,aspect='auto')
ax3 = fig.add_subplot(133)
ax3 = imshow(np.rot90(np.mean(np.nan_to_num(test[0].data[27:,:,6:]),axis = 2)),cmap = 'viridis',vmin = -30,vmax = 30,aspect='auto')
#cbar1 = fig.colorbar(ax1)
cbar3 = fig.colorbar(ax3)
plt.show()
test[0].header
# Out:
# Populating the interactive namespace from numpy and matplotlib
# (129, 2040, 8)
# /home/sean/anaconda3/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['test']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# -75.67246733560648
# 78.73172623825927
# 3.7882755368646017
# SIMPLE  =                    T / Written by IDL:  Fri Oct 20 15:38:57 2017
# BITPIX  =                  -64 / Number of bits per data pixel
# NAXIS   =                    3 / Number of data axes
# NAXIS1  =                    8
# NAXIS2  =                 2040
# NAXIS3  =                  129
# EXTEND  =                    T / FITS data may contain extensions
# INSTRUME= 'IRIS    '           / Data generated in IRIS format
# DATA_LEV=              3.00000 / Data level
# LVL_NUM =              3.00000 / Data level
# ...

# %%
# %pylab inline
from astropy.io import fits
from scipy.optimize import curve_fit
from scipy.interpolate import interp1d

test = fits.open("MgII_2796_bisector_velocities.fits")
print(test[0].data.shape)
print(np.amin(np.nan_to_num(test[0].data[:,:,5])))
print(np.amax(np.nan_to_num(test[0].data[:,:,5])))
print(np.mean(np.abs(np.nan_to_num(test[0].data[:,:,5])[np.nan_to_num(test[0].data[:,:,5]) != 0.])))
fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(131)
ax = imshow(np.rot90(np.mean(np.nan_to_num(test[0].data[27:,:,0:3]),axis = 2)),cmap = 'viridis',vmin = -30,vmax = 30,aspect='auto')
ax2 = fig.add_subplot(132)
ax2 = imshow(np.rot90(np.mean(np.nan_to_num(test[0].data[27:,:,3:6]),axis = 2)),cmap = 'viridis',vmin = -30,vmax = 30,aspect='auto')
ax3 = fig.add_subplot(133)
ax3 = imshow(np.rot90(np.mean(np.nan_to_num(test[0].data[27:,:,6:]),axis = 2)),cmap = 'viridis',vmin = -30,vmax = 30,aspect='auto')
#cbar1 = fig.colorbar(ax1)
cbar3 = fig.colorbar(ax3)
plt.show()
test[0].header
# Out:
# Populating the interactive namespace from numpy and matplotlib
# (129, 2040, 8)
# /home/sean/anaconda3/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['test']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# -75.67246733560648
# 78.73172623825927
# 3.7882755368646017
# SIMPLE  =                    T / Written by IDL:  Fri Oct 20 15:38:57 2017
# BITPIX  =                  -64 / Number of bits per data pixel
# NAXIS   =                    3 / Number of data axes
# NAXIS1  =                    8
# NAXIS2  =                 2040
# NAXIS3  =                  129
# EXTEND  =                    T / FITS data may contain extensions
# INSTRUME= 'IRIS    '           / Data generated in IRIS format
# DATA_LEV=              3.00000 / Data level
# LVL_NUM =              3.00000 / Data level
# ...

# %%
# %pylab inline
from astropy.io import fits
from scipy.optimize import curve_fit
from scipy.interpolate import interp1d

test = fits.open("MgII_2804_bisector_velocities.fits")

starttime = test[0].header["STARTOBS"]
iris_data = fits.open("/home/sean/Research/iris/iris_bisector_fits/25/iris_l3_20141025_145828_3880106953_t000_all_sp.fits")
time_obs = np.array(iris_data[2].data,dtype='timedelta64[s]') + np.datetime64(starttime,dtype = "datetime64[s]")
time_obs = np.array(time_obs,dtype = 'datetime64[s]')

print(test[0].data.shape)
print(np.amin(np.nan_to_num(test[0].data[:,:,5])))
print(np.amax(np.nan_to_num(test[0].data[:,:,5])))
print(np.mean(np.abs(np.nan_to_num(test[0].data[:,:,5])[np.nan_to_num(test[0].data[:,:,5]) != 0.])))
fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(131)
ax = imshow(np.rot90(np.mean(np.nan_to_num(test[0].data[:,:,0:3]),axis = 2)),cmap = 'viridis',vmin = -30,vmax = 30,aspect='auto',extent = [27,129,time_obs[-1],time_obs[0]])
ax2 = fig.add_subplot(132)
ax2 = imshow(np.rot90(np.mean(np.nan_to_num(test[0].data[27:,:,3:6]),axis = 2)),cmap = 'viridis',vmin = -30,vmax = 30,aspect='auto')
ax3 = fig.add_subplot(133)
ax3 = imshow(np.rot90(np.mean(np.nan_to_num(test[0].data[27:,:,6:]),axis = 2)),cmap = 'viridis',vmin = -30,vmax = 30,aspect='auto')
fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
fig.colorbar(ax3, cax=cbar_ax)
plt.show()
test[0].header
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/sean/anaconda3/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['test']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-31-f2dedab4b051> in <module>()
#       8 starttime = test[0].header["STARTOBS"]
#       9 iris_data = fits.open("/home/sean/Research/iris/iris_bisector_fits/25/iris_l3_20141025_145828_3880106953_t000_all_sp.fits")
# ---> 10 time_obs = np.array(iris_data[2].data,dtype='timedelta64[s]') + np.datetime64(starttime,dtype = "datetime64[s]")
#      11 time_obs = np.array(time_obs,dtype = 'datetime64[s]')
#      12
#
# ...
